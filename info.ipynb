# %%
import os
from collections import Counter, defaultdict

DATA_DIR = "data/Sagittal_T1_FLAIR"  # change if needed

patient_counter = Counter()
patient_files = defaultdict(list)

for fname in os.listdir(DATA_DIR):
    if fname.endswith(".nii.gz"):
        try:
            # patient ID = number before first "_"
            patient_id = int(fname.split("_")[0])
            patient_counter[patient_id] += 1
            patient_files[patient_id].append(fname)
        except ValueError:
            print(f"Could not parse patient ID from: {fname}")

print("\n================ SUMMARY ================")
print(f"Total files          : {sum(patient_counter.values())}")
print(f"Unique patients      : {len(patient_counter)}")
print(f"Repeated patients    : {sum(1 for p in patient_counter if patient_counter[p] > 1)}")

print("\n=========== PATIENT SCAN COUNTS ==========")
for pid, count in sorted(patient_counter.items()):
    print(f"Patient {pid:>3} -> {count} scan(s)")

print("\n====== PATIENTS WITH MULTIPLE SCANS ======")
for pid, files in sorted(patient_files.items()):
    if len(files) > 1:
        print(f"\nPatient {pid} ({len(files)} scans):")
        for f in files:
            print(f"   {f}")
# Out:
# Could not parse patient ID from: 436@_20200819_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
# Could not parse patient ID from: 368@_20200805_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#
# ================ SUMMARY ================
# Total files          : 240
# Unique patients      : 231
# Repeated patients    : 9
#
# =========== PATIENT SCAN COUNTS ==========
# Patient   1 -> 1 scan(s)
# Patient   2 -> 1 scan(s)
# Patient   3 -> 1 scan(s)
# Patient   6 -> 2 scan(s)
# Patient   9 -> 1 scan(s)
# Patient  10 -> 1 scan(s)
# Patient  12 -> 1 scan(s)
# Patient  13 -> 1 scan(s)
# Patient  14 -> 1 scan(s)
# Patient  15 -> 1 scan(s)
# Patient  18 -> 1 scan(s)
# Patient  22 -> 1 scan(s)
# Patient  23 -> 1 scan(s)
# Patient  26 -> 1 scan(s)
# Patient  31 -> 1 scan(s)
# Patient  33 -> 1 scan(s)
# Patient  36 -> 1 scan(s)
# Patient  37 -> 1 scan(s)
# Patient  39 -> 1 scan(s)
# Patient  42 -> 1 scan(s)
# Patient  46 -> 1 scan(s)
# Patient  48 -> 1 scan(s)
# Patient  55 -> 1 scan(s)
# Patient  58 -> 1 scan(s)
# Patient  65 -> 1 scan(s)
# Patient  67 -> 1 scan(s)
# Patient  68 -> 1 scan(s)
# Patient  71 -> 1 scan(s)
# Patient  73 -> 1 scan(s)
# Patient  74 -> 1 scan(s)
# Patient  76 -> 1 scan(s)
# Patient  79 -> 1 scan(s)
# Patient  80 -> 1 scan(s)
# Patient  88 -> 1 scan(s)
# Patient  89 -> 1 scan(s)
# Patient  90 -> 1 scan(s)
# Patient  95 -> 1 scan(s)
# Patient 100 -> 1 scan(s)
# Patient 102 -> 1 scan(s)
# Patient 104 -> 1 scan(s)
# Patient 105 -> 1 scan(s)
# Patient 106 -> 1 scan(s)
# Patient 107 -> 1 scan(s)
# Patient 108 -> 1 scan(s)
# Patient 110 -> 1 scan(s)
# Patient 111 -> 1 scan(s)
# Patient 112 -> 1 scan(s)
# Patient 114 -> 1 scan(s)
# Patient 116 -> 1 scan(s)
# Patient 122 -> 1 scan(s)
# Patient 123 -> 1 scan(s)
# Patient 125 -> 2 scan(s)
# Patient 128 -> 1 scan(s)
# Patient 129 -> 1 scan(s)
# Patient 131 -> 1 scan(s)
# Patient 132 -> 1 scan(s)
# Patient 134 -> 1 scan(s)
# Patient 136 -> 1 scan(s)
# Patient 137 -> 1 scan(s)
# Patient 140 -> 1 scan(s)
# Patient 144 -> 1 scan(s)
# Patient 148 -> 1 scan(s)
# Patient 151 -> 1 scan(s)
# Patient 155 -> 1 scan(s)
# Patient 157 -> 1 scan(s)
# Patient 158 -> 1 scan(s)
# Patient 160 -> 1 scan(s)
# Patient 162 -> 1 scan(s)
# Patient 163 -> 1 scan(s)
# Patient 164 -> 1 scan(s)
# Patient 165 -> 1 scan(s)
# Patient 166 -> 2 scan(s)
# Patient 167 -> 1 scan(s)
# Patient 174 -> 1 scan(s)
# Patient 176 -> 1 scan(s)
# Patient 178 -> 1 scan(s)
# Patient 179 -> 1 scan(s)
# Patient 180 -> 1 scan(s)
# Patient 183 -> 1 scan(s)
# Patient 185 -> 1 scan(s)
# Patient 187 -> 1 scan(s)
# Patient 189 -> 1 scan(s)
# Patient 193 -> 1 scan(s)
# Patient 195 -> 1 scan(s)
# Patient 196 -> 1 scan(s)
# Patient 199 -> 1 scan(s)
# Patient 200 -> 1 scan(s)
# Patient 201 -> 1 scan(s)
# Patient 202 -> 1 scan(s)
# Patient 205 -> 1 scan(s)
# Patient 211 -> 1 scan(s)
# Patient 212 -> 1 scan(s)
# Patient 221 -> 1 scan(s)
# Patient 222 -> 1 scan(s)
# Patient 223 -> 1 scan(s)
# Patient 226 -> 1 scan(s)
# Patient 227 -> 1 scan(s)
# Patient 238 -> 1 scan(s)
# Patient 242 -> 1 scan(s)
# Patient 246 -> 1 scan(s)
# Patient 251 -> 1 scan(s)
# Patient 254 -> 1 scan(s)
# Patient 256 -> 1 scan(s)
# Patient 266 -> 1 scan(s)
# Patient 267 -> 2 scan(s)
# Patient 268 -> 1 scan(s)
# Patient 269 -> 1 scan(s)
# Patient 270 -> 1 scan(s)
# Patient 275 -> 1 scan(s)
# Patient 280 -> 1 scan(s)
# Patient 281 -> 1 scan(s)
# Patient 282 -> 1 scan(s)
# Patient 284 -> 1 scan(s)
# Patient 288 -> 1 scan(s)
# Patient 290 -> 1 scan(s)
# Patient 293 -> 1 scan(s)
# Patient 294 -> 1 scan(s)
# Patient 297 -> 1 scan(s)
# Patient 300 -> 1 scan(s)
# Patient 304 -> 1 scan(s)
# Patient 309 -> 1 scan(s)
# Patient 310 -> 1 scan(s)
# Patient 314 -> 1 scan(s)
# Patient 316 -> 1 scan(s)
# Patient 319 -> 1 scan(s)
# Patient 321 -> 1 scan(s)
# Patient 322 -> 1 scan(s)
# Patient 324 -> 1 scan(s)
# Patient 328 -> 1 scan(s)
# Patient 333 -> 1 scan(s)
# Patient 335 -> 1 scan(s)
# Patient 338 -> 1 scan(s)
# Patient 343 -> 1 scan(s)
# Patient 344 -> 1 scan(s)
# Patient 345 -> 1 scan(s)
# Patient 346 -> 2 scan(s)
# Patient 350 -> 1 scan(s)
# Patient 351 -> 1 scan(s)
# Patient 353 -> 1 scan(s)
# Patient 355 -> 1 scan(s)
# Patient 356 -> 1 scan(s)
# Patient 367 -> 2 scan(s)
# Patient 375 -> 1 scan(s)
# Patient 376 -> 2 scan(s)
# Patient 379 -> 1 scan(s)
# Patient 381 -> 1 scan(s)
# Patient 383 -> 1 scan(s)
# Patient 386 -> 1 scan(s)
# Patient 388 -> 1 scan(s)
# Patient 391 -> 1 scan(s)
# Patient 394 -> 1 scan(s)
# Patient 395 -> 1 scan(s)
# Patient 396 -> 1 scan(s)
# Patient 397 -> 1 scan(s)
# Patient 400 -> 1 scan(s)
# Patient 401 -> 1 scan(s)
# Patient 402 -> 1 scan(s)
# Patient 403 -> 1 scan(s)
# Patient 413 -> 1 scan(s)
# Patient 415 -> 1 scan(s)
# Patient 418 -> 1 scan(s)
# Patient 420 -> 1 scan(s)
# Patient 422 -> 1 scan(s)
# Patient 424 -> 1 scan(s)
# Patient 434 -> 1 scan(s)
# Patient 435 -> 1 scan(s)
# Patient 439 -> 2 scan(s)
# Patient 444 -> 1 scan(s)
# Patient 447 -> 1 scan(s)
# Patient 449 -> 1 scan(s)
# Patient 457 -> 1 scan(s)
# Patient 460 -> 1 scan(s)
# Patient 464 -> 1 scan(s)
# Patient 465 -> 1 scan(s)
# Patient 469 -> 1 scan(s)
# Patient 472 -> 1 scan(s)
# Patient 476 -> 1 scan(s)
# Patient 479 -> 1 scan(s)
# Patient 480 -> 1 scan(s)
# Patient 482 -> 1 scan(s)
# Patient 483 -> 1 scan(s)
# Patient 484 -> 1 scan(s)
# Patient 486 -> 1 scan(s)
# Patient 492 -> 1 scan(s)
# Patient 495 -> 1 scan(s)
# Patient 496 -> 1 scan(s)
# Patient 497 -> 1 scan(s)
# Patient 503 -> 1 scan(s)
# Patient 505 -> 1 scan(s)
# Patient 506 -> 1 scan(s)
# Patient 507 -> 1 scan(s)
# Patient 510 -> 1 scan(s)
# Patient 512 -> 1 scan(s)
# Patient 513 -> 1 scan(s)
# Patient 514 -> 1 scan(s)
# Patient 515 -> 1 scan(s)
# Patient 518 -> 1 scan(s)
# Patient 521 -> 1 scan(s)
# Patient 522 -> 1 scan(s)
# Patient 523 -> 1 scan(s)
# Patient 524 -> 1 scan(s)
# Patient 525 -> 1 scan(s)
# Patient 530 -> 1 scan(s)
# Patient 532 -> 1 scan(s)
# Patient 534 -> 1 scan(s)
# Patient 538 -> 1 scan(s)
# Patient 539 -> 1 scan(s)
# Patient 542 -> 1 scan(s)
# Patient 547 -> 1 scan(s)
# Patient 552 -> 1 scan(s)
# Patient 553 -> 1 scan(s)
# Patient 554 -> 1 scan(s)
# Patient 555 -> 1 scan(s)
# Patient 557 -> 1 scan(s)
# Patient 560 -> 2 scan(s)
# Patient 562 -> 1 scan(s)
# Patient 563 -> 1 scan(s)
# Patient 564 -> 1 scan(s)
# Patient 565 -> 1 scan(s)
# Patient 567 -> 1 scan(s)
# Patient 569 -> 1 scan(s)
# Patient 571 -> 1 scan(s)
# Patient 577 -> 1 scan(s)
# Patient 580 -> 1 scan(s)
# Patient 585 -> 1 scan(s)
# Patient 587 -> 1 scan(s)
# Patient 588 -> 1 scan(s)
# Patient 591 -> 1 scan(s)
# Patient 592 -> 1 scan(s)
# Patient 595 -> 1 scan(s)
# Patient 597 -> 1 scan(s)
#
# ====== PATIENTS WITH MULTIPLE SCANS ======
#
# Patient 6 (2 scans):
#    6_20220722_Lumbar_Spine_Sagittal_T1_FLAIR_s4_1.nii.gz
#    6_20220722_Lumbar_Spine_Sagittal_T1_FLAIR_s4.nii.gz
#
# Patient 125 (2 scans):
#    125_20220808_Lumbar_Spine_Sagittal_T1_FLAIR_s10.nii.gz
#    125_20220808_Lumbar_Spine_Sagittal_T1_FLAIR_s6.nii.gz
#
# Patient 166 (2 scans):
#    166_20240113_Lumbar_Spine_Sagittal_T1_FLAIR_s7.nii.gz
#    166_20240113_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#
# Patient 267 (2 scans):
#    267_20241203_Lumbar_Spine_Sagittal_T1_FLAIR_s9.nii.gz
#    267_20241203_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#
# Patient 346 (2 scans):
#    346_20230328_Lumbar_Spine_Sagittal_T1_FLAIR_s12.nii.gz
#    346_20230328_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#
# Patient 367 (2 scans):
#    367_20211122_Lumbar_Spine_Sagittal_T1_FLAIR_s8.nii.gz
#    367_20211122_Lumbar_Spine_Sagittal_T1_FLAIR_s4.nii.gz
#
# Patient 376 (2 scans):
#    376_20231209_Lumbar_Spine_Sagittal_T1_FLAIR_s9.nii.gz
#    376_20231209_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#
# Patient 439 (2 scans):
#    439_20210824_Lumbar_Spine_Sagittal_T1_FLAIR_s10.nii.gz
#    439_20210824_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#
# Patient 560 (2 scans):
#    560_20240303_Lumbar_Spine_Sagittal_T1_FLAIR_s10.nii.gz
#    560_20240303_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz

# %%
import os, re
import pandas as pd
from collections import Counter, defaultdict

DATA_DIR = "data/Sagittal_T1_FLAIR"     # change if needed
XLSX_PATH = "data/metadata.xlsx"        # change if needed

def parse_patient_id(filename: str):
    """
    Robustly extract patient ID from start of filename:
    Examples:
      '368@_20200805_...' -> 368
      '368_20200805_...'  -> 368
    """
    first_token = filename.split("_")[0]
    m = re.search(r"\d+", first_token)
    return int(m.group()) if m else None

# --------- load metadata ----------
df = pd.read_excel(XLSX_PATH)

# basic column check
required = {"ID", "BMD"}
missing_cols = required - set(df.columns)
if missing_cols:
    raise ValueError(f"metadata.xlsx missing columns: {missing_cols}. Found: {list(df.columns)}")

# coerce types
df["ID"] = pd.to_numeric(df["ID"], errors="coerce").astype("Int64")
df["BMD"] = pd.to_numeric(df["BMD"], errors="coerce")

df_bad = df[df["ID"].isna() | df["BMD"].isna()]
if len(df_bad) > 0:
    print("\nWARNING: Rows with invalid ID or BMD (these will be ignored):")
    print(df_bad)

df_clean = df.dropna(subset=["ID", "BMD"]).copy()
df_clean["ID"] = df_clean["ID"].astype(int)

# duplicates in metadata
dup_ids = df_clean["ID"][df_clean["ID"].duplicated()].unique().tolist()

meta_ids = set(df_clean["ID"].tolist())
meta_map = dict(zip(df_clean["ID"], df_clean["BMD"]))

# --------- scan files ----------
file_ids = []
id_to_files = defaultdict(list)
all_files = [f for f in os.listdir(DATA_DIR) if f.endswith(".nii.gz")]

unparsed = []
for f in all_files:
    pid = parse_patient_id(f)
    if pid is None:
        unparsed.append(f)
        continue
    file_ids.append(pid)
    id_to_files[pid].append(f)

file_id_counts = Counter(file_ids)
folder_ids = set(file_id_counts.keys())

# --------- compare ----------
ids_in_files_not_in_meta = sorted(list(folder_ids - meta_ids))
ids_in_meta_not_in_files = sorted(list(meta_ids - folder_ids))
ids_common = sorted(list(folder_ids & meta_ids))

print("\n=================== SUMMARY ===================")
print(f"Total .nii.gz files                 : {len(all_files)}")
print(f"Files with parsed patient IDs       : {sum(file_id_counts.values())}")
print(f"Files that FAILED ID parsing        : {len(unparsed)}")
print(f"Unique patient IDs in folder        : {len(folder_ids)}")
print(f"Unique patient IDs in metadata      : {len(meta_ids)}")
print(f"Patient IDs present in BOTH         : {len(ids_common)}")

print("\n=============== METADATA QUALITY ===============")
print(f"Duplicate IDs in metadata           : {len(dup_ids)}")
if dup_ids:
    print("Duplicate ID examples:", dup_ids[:20])

print("\n=============== MISMATCH REPORT ================")
print(f"IDs in folder but NOT in metadata   : {len(ids_in_files_not_in_meta)}")
print(f"IDs in metadata but NOT in folder   : {len(ids_in_meta_not_in_files)}")

if ids_in_files_not_in_meta:
    print("\nFirst 25 IDs in folder missing metadata:", ids_in_files_not_in_meta[:25])

if ids_in_meta_not_in_files:
    print("\nFirst 25 IDs in metadata missing files:", ids_in_meta_not_in_files[:25])

print("\n=========== REPEATED PATIENTS (folder) =========")
repeated = [(pid, c) for pid, c in file_id_counts.items() if c > 1]
repeated.sort(key=lambda x: (-x[1], x[0]))
print(f"Patients with >1 scan in folder     : {len(repeated)}")
for pid, c in repeated[:30]:
    print(f"Patient {pid} -> {c} scans")

if repeated:
    print("\nExample files for first 5 repeated patients:")
    for pid, c in repeated[:5]:
        print(f"\nPatient {pid} ({c} scans):")
        for f in sorted(id_to_files[pid])[:10]:
            print("  ", f)

if unparsed:
    print("\n=========== UNPARSED FILENAMES ===========")
    for f in unparsed[:20]:
        print("  ", f)
    if len(unparsed) > 20:
        print(f"  ... and {len(unparsed)-20} more")
# Out:
# =================== SUMMARY ===================
# Total .nii.gz files                 : 242
# Files with parsed patient IDs       : 242
# Files that FAILED ID parsing        : 0
# Unique patient IDs in folder        : 233
# Unique patient IDs in metadata      : 231
# Patient IDs present in BOTH         : 231
#
# =============== METADATA QUALITY ===============
# Duplicate IDs in metadata           : 0
#
# =============== MISMATCH REPORT ================
# IDs in folder but NOT in metadata   : 2
# IDs in metadata but NOT in folder   : 0
#
# First 25 IDs in folder missing metadata: [368, 436]
#
# =========== REPEATED PATIENTS (folder) =========
# Patients with >1 scan in folder     : 9
# Patient 6 -> 2 scans
# Patient 125 -> 2 scans
# Patient 166 -> 2 scans
# Patient 267 -> 2 scans
# Patient 346 -> 2 scans
# Patient 367 -> 2 scans
# Patient 376 -> 2 scans
# Patient 439 -> 2 scans
# Patient 560 -> 2 scans
#
# Example files for first 5 repeated patients:
#
# Patient 6 (2 scans):
#    6_20220722_Lumbar_Spine_Sagittal_T1_FLAIR_s4.nii.gz
#    6_20220722_Lumbar_Spine_Sagittal_T1_FLAIR_s4_1.nii.gz
#
# Patient 125 (2 scans):
#    125_20220808_Lumbar_Spine_Sagittal_T1_FLAIR_s10.nii.gz
#    125_20220808_Lumbar_Spine_Sagittal_T1_FLAIR_s6.nii.gz
#
# Patient 166 (2 scans):
#    166_20240113_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#    166_20240113_Lumbar_Spine_Sagittal_T1_FLAIR_s7.nii.gz
#
# Patient 267 (2 scans):
#    267_20241203_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz
#    267_20241203_Lumbar_Spine_Sagittal_T1_FLAIR_s9.nii.gz
#
# Patient 346 (2 scans):
#    346_20230328_Lumbar_Spine_Sagittal_T1_FLAIR_s12.nii.gz
#    346_20230328_Lumbar_Spine_Sagittal_T1_FLAIR_s5.nii.gz

# %%
import nibabel as nib
import numpy as np

# ✅ change this to ONE of your .nii or .nii.gz paths
path = r"data/Sagittal_T1_FLAIR/100_20220730_Lumbar_Spine_Sagittal_T1_FLAIR_s6.nii.gz"

img = nib.load(path)
data = img.get_fdata()   # float array
aff = img.affine

print("File:", path)
print("Shape (X,Y,Z,...) :", data.shape)
print("Affine:\n", aff)

# Orientation: which array axis corresponds to L/R, P/A, I/S in real space
try:
    axcodes = nib.aff2axcodes(aff)  # e.g. ('R','A','S')
    print("Orientation codes (axis0,axis1,axis2):", axcodes)

    # Sagittal = Left/Right axis => 'L' or 'R'
    sag_axis = None
    for i, c in enumerate(axcodes[:3]):
        if c in ("L", "R"):
            sag_axis = i
            break

    print("Sagittal axis index:", sag_axis)

    if sag_axis == 0:
        print("Sagittal slicing: data[mid, :, :]   (axis 0)")
    elif sag_axis == 1:
        print("Sagittal slicing: data[:, mid, :]   (axis 1)")
    elif sag_axis == 2:
        print("Sagittal slicing: data[:, :, mid]   (axis 2)")
    else:
        print("Could not detect sagittal axis (unexpected orientation).")

except Exception as e:
    print("Orientation detection failed:", e)

# Also show what YOUR CURRENT code is doing if you slice [:,:,mid]
if data.ndim >= 3:
    mid = data.shape[2] // 2
    sl = data[:, :, mid]
    print("\nIf you do data[:, :, mid], slice shape =", sl.shape, "(this is what your current slicing would output)")
# Out:
# File: data/Sagittal_T1_FLAIR/100_20220730_Lumbar_Spine_Sagittal_T1_FLAIR_s6.nii.gz
# Shape (X,Y,Z,...) : (512, 512, 18)
# Affine:
#  [[-1.39474599e-02 -1.65454186e-02  4.49647141e+00 -2.76760006e+01]
#  [-5.46721518e-01 -3.56541481e-04 -1.14903599e-01  1.73287994e+02]
#  [ 7.78735674e-04 -5.46649516e-01 -1.36019558e-01  3.66510010e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Orientation codes (axis0,axis1,axis2): ('P', 'I', 'R')
# Sagittal axis index: 2
# Sagittal slicing: data[:, :, mid]   (axis 2)
#
# If you do data[:, :, mid], slice shape = (512, 512) (this is what your current slicing would output)
